# %%
import pandas as pd 
import numpy as np 


data = pd.read_csv("./data/player_stats_202122.csv", sep=';', encoding='ISO-8859-1')
data.head(5)
# Out:
#    Rk             Player Nation Pos          Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF   Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF          Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF  Clermont Foot         Ligue 1  22.0
# 3   4    Laurent Abergel    FRA  MF        Lorient         Ligue 1  29.0
# 4   5        Charles Abi    FRA  FW  Saint-Étienne         Ligue 1  22.0
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  34      32  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53    0.47
# 1  1987  34      34  ...  0.00  0.06  1.39    0.0   0.03  0.00   6.77    2.02
# 2  2000  31      29  ...  0.00  0.36  1.24    0.0   0.00  0.00   8.76    0.88
# 3  1993  34      34  ...  0.03  0.79  2.23    0.0   0.00  0.00   8.87    0.43
# 4  2000   1       1  ...  0.00  2.00  0.00    0.0   0.00  0.00   4.00    2.00
#
#    AerLost  AerWon%
# 0     1.59     22.7
# ...

# %%
data.columns[data.isnull().any()].tolist()
# Out:
# ['Nation', 'Age']

# %%
football_player_stats = pd.DataFrame()

football_player_stats['Player'] = data['Player']
football_player_stats['Nation'] = data['Nation']
football_player_stats['Squad'] = data['Squad']
football_player_stats['League'] = data['Comp']
football_player_stats['Age'] = data['Age']
football_player_stats['MP'] = data['MP']
football_player_stats['Position'] = data['Pos']
football_player_stats['Goals/90'] = data['Goals']
football_player_stats['Goals/Shot'] = data['G/Sh']
football_player_stats['Shots'] = data['Shots']
football_player_stats['TouchesDefPen'] = data['TouDefPen']
football_player_stats['TouchesDef3rd'] = data['TouDef3rd']
football_player_stats['TouchesMid3rd'] = data['TouMid3rd']
football_player_stats['TouchesAtt3rd'] = data['TouAtt3rd']
football_player_stats['TouchesAttPen'] = data['TouAttPen']
football_player_stats['BlocksOnTargetShots'] = data['BlkShSv']
football_player_stats['BlocksShots'] = data['BlkSh']
football_player_stats['BlocksPasses'] = data['BlkPass']
football_player_stats['Blocks'] = (data['Blocks'] - (data['BlkShSv'] + data['BlkSh'] + data['BlkPass'])).round(0).astype(int)
football_player_stats['PKGoals'] = ((data['ShoPK'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['PKAttempted'] = ((data['PKatt'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['Goals'] = ((data['Goals'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['Pass'] = ((data['PasTotAtt'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['PassCompleted'] = ((data['PasTotCmp'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['PassComp%'] = ((football_player_stats['PassCompleted'] / football_player_stats['Pass']) * 100).round(2)
football_player_stats['Assist'] = ((data['Assists'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['Cross'] = ((data['PasCrs'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['CrossCompleted'] = ((data['CrsPA'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['CrossComp%'] = ((football_player_stats['CrossCompleted'] / football_player_stats['Cross']) * 100).round(2)
football_player_stats['Tackle_Won'] = ((data['TklWon'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['SucDribble'] = ((data['DriSucc'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['Dribble'] = ((data['DriAtt'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['DribbleComp%'] = ((football_player_stats['SucDribble'] / football_player_stats['Dribble']) * 100).round(2)
football_player_stats['YCards'] = ((data['CrdY'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['RCards'] = ((data['CrdR'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['FoulsCommitted'] = ((data['Fls'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['FoulsDrawn'] = ((data['Fld'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['OGoals'] = ((data['OG'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['AerWon'] = ((data['AerWon'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['AerLost'] = ((data['AerLost'] * data['Min']) / 90).round(0).astype(int)
football_player_stats['AerWon%'] = ((data['AerWon'] / (data['AerWon'] + data['AerLost'])) * 100).round(2)

football_player_stats.head()
# Out:
#               Player Nation          Squad          League   Age  MP Position  \
# 0         Max Aarons    ENG   Norwich City  Premier League  22.0  34       DF
# 1   Yunis Abdelhamid    MAR          Reims         Ligue 1  34.0  34       DF
# 2  Salis Abdul Samed    GHA  Clermont Foot         Ligue 1  22.0  31       MF
# 3    Laurent Abergel    FRA        Lorient         Ligue 1  29.0  34       MF
# 4        Charles Abi    FRA  Saint-Étienne         Ligue 1  22.0   1       FW
#
#    Goals/90  Goals/Shot  Shots  ...  Dribble  DribbleComp%  YCards  RCards  \
# 0      0.00        0.00   0.41  ...       78         42.31       8       0
# 1      0.06        0.11   0.54  ...       22         72.73       5       1
# 2      0.04        0.06   0.66  ...       42         64.29      12       3
# 3      0.00        0.00   0.91  ...       65         64.62       9       0
# 4      0.00        0.00   0.00  ...        0           NaN       0       0
#
# ...

# %%
football_player_stats.keys()
# Out:
# Index(['Player', 'Nation', 'Squad', 'League', 'Age', 'MP', 'Position',
#        'Goals/90', 'Goals/Shot', 'Shots', 'TouchesDefPen', 'TouchesDef3rd',
#        'TouchesMid3rd', 'TouchesAtt3rd', 'TouchesAttPen',
#        'BlocksOnTargetShots', 'BlocksShots', 'BlocksPasses', 'Blocks',
#        'PKGoals', 'PKAttempted', 'Goals', 'Pass', 'PassCompleted', 'PassComp%',
#        'Assist', 'Cross', 'CrossCompleted', 'CrossComp%', 'Tackle_Won',
#        'SucDribble', 'Dribble', 'DribbleComp%', 'YCards', 'RCards',
#        'FoulsCommitted', 'FoulsDrawn', 'OGoals', 'AerWon', 'AerLost',
#        'AerWon%'],
#       dtype='object')

# %% [markdown]
# We group the above attributes into the following categories:
#
# ## Attatcking Stats:
# - Goals/90 :
# - Goals/Shot :
# - Shots :
# - PKGoals :
# - PKAttempted :
# - Goals :
# - TouchesAtt3rd :
# - TouchesAttPen :
#
# ## Passing Stats:
# - Pass :
# - PassCompleted :
# - PassComp% :
#
# ## Creativity:
# - Assist :
# - Cross :
# - CrossCompleted :
# - CrossComp% :
# - FoulsDrawn
#
# ## Tackles:
# - Tackles_Won:
# - TouchesDefPen
# - TouchesDef3rd
# - AerWon
# - AerLost
#
# <!-- ## Pressing: -->
#
# ## Blocks:
# - Blocks
# - BlocksShots
# - BlocksShotsOnTarget
# - BlocksPasses
#
# ## Dribbling:
# - SucDribble
# - Dribble
# - DribbleComp%
#
# ## Indiscipline:
# - Ycards
# - RCards
# - FoulsCommitted

# %%
Attack_Stats = football_player_stats[["Player","Goals/90","Goals/Shot", "Shots", "PKGoals", "PKAttempted", "Goals", "TouchesAtt3rd", "TouchesAttPen"]]

Att_weights = [1,1,1,1,1,1,1,1]
Attack_Stats["Combined"] = Attack_Stats.iloc[:,1:].mul(Att_weights).sum(axis=1)

Attack_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/1397239623.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Attack_Stats["Combined"] = Attack_Stats.iloc[:,1:].mul(Att_weights).sum(axis=1)
#               Player  Goals/90  Goals/Shot  Shots  PKGoals  PKAttempted  \
# 0         Max Aarons      0.00        0.00   0.41        0            0
# 1   Yunis Abdelhamid      0.06        0.11   0.54        0            0
# 2  Salis Abdul Samed      0.04        0.06   0.66        0            0
# 3    Laurent Abergel      0.00        0.00   0.91        0            0
# 4        Charles Abi      0.00        0.00   0.00        0            0
#
#    Goals  TouchesAtt3rd  TouchesAttPen  Combined
# ...

# %%
Pass_Stats = football_player_stats[["Player","Pass", "PassCompleted", "PassComp%"]]

Pass_weights = [1,1,1]
Pass_Stats["Combined"] = Pass_Stats.iloc[:,1:].mul(Pass_weights).sum(axis=1)

Pass_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/3405559761.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pass_Stats["Combined"] = Pass_Stats.iloc[:,1:].mul(Pass_weights).sum(axis=1)
#               Player  Pass  PassCompleted  PassComp%  Combined
# 0         Max Aarons  1440           1088      75.56   2603.56
# 1   Yunis Abdelhamid  1558           1283      82.35   2923.35
# 2  Salis Abdul Samed  1669           1529      91.61   3289.61
# 3    Laurent Abergel  1636           1337      81.72   3054.72
# 4        Charles Abi     6              2      33.33     41.33

# %%
Crea_Stats = football_player_stats[["Player","Assist","Cross", "CrossCompleted", "CrossComp%","FoulsDrawn"]]

Crea_weights = [1,1,1,1,1]
Crea_Stats["Combined"] = Crea_Stats.iloc[:,1:].mul(Crea_weights).sum(axis=1)

Crea_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/4261047683.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Crea_Stats["Combined"] = Crea_Stats.iloc[:,1:].mul(Crea_weights).sum(axis=1)
#               Player  Assist  Cross  CrossCompleted  CrossComp%  FoulsDrawn  \
# 0         Max Aarons       2     45               8       17.78          59
# 1   Yunis Abdelhamid       0      2               0        0.00          24
# 2  Salis Abdul Samed       0     10               1       10.00          35
# 3    Laurent Abergel       2     26               6       23.08          68
# 4        Charles Abi       0      1               0        0.00           0
#
#    Combined
# 0    131.78
# 1     26.00
# 2     56.00
# ...

# %%
Tack_Stats = football_player_stats[["Player","Tackle_Won", "TouchesDefPen", "TouchesDef3rd","AerWon","AerLost"]]

Tack_weights = [1,1,1,1,1]
Tack_Stats["Combined"] = Tack_Stats.iloc[:,1:].mul(Tack_weights).sum(axis=1)

Tack_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/922401115.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tack_Stats["Combined"] = Tack_Stats.iloc[:,1:].mul(Tack_weights).sum(axis=1)
#               Player  Tackle_Won  TouchesDefPen  TouchesDef3rd  AerWon  \
# 0         Max Aarons          37           5.06           23.3      15
# 1   Yunis Abdelhamid          46           8.28           32.8      67
# 2  Salis Abdul Samed          34           2.01           22.7      24
# 3    Laurent Abergel          73           0.67           13.7      14
# 4        Charles Abi           0           0.00            0.0       1
#
#    AerLost  Combined
# 0       51    131.36
# 1       45    199.08
# 2       24    106.71
# ...

# %%
Block_Stats = football_player_stats[["Player","Blocks", "BlocksShots", "BlocksOnTargetShots","BlocksPasses"]]

Block_weights = [1,1,1,1]
Block_Stats["Combined"] = Block_Stats.iloc[:,1:].mul(Block_weights).sum(axis=1)

Block_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/3292476354.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Block_Stats["Combined"] = Block_Stats.iloc[:,1:].mul(Block_weights).sum(axis=1)
#               Player  Blocks  BlocksShots  BlocksOnTargetShots  BlocksPasses  \
# 0         Max Aarons       0         0.69                 0.03          2.00
# 1   Yunis Abdelhamid       0         0.79                 0.06          1.09
# 2  Salis Abdul Samed       0         0.04                 0.00          0.95
# 3    Laurent Abergel       0         0.09                 0.00          1.59
# 4        Charles Abi       0         0.00                 0.00          2.00
#
#    Combined
# 0      2.72
# 1      1.94
# 2      0.99
# ...

# %%
Drib_Stats = football_player_stats[["Player","SucDribble", "Dribble", "DribbleComp%"]]

Drib_weights = [1,1,1]
Drib_Stats["Combined"] = Drib_Stats.iloc[:,1:].mul(Drib_weights).sum(axis=1)

Drib_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/41964214.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Drib_Stats["Combined"] = Drib_Stats.iloc[:,1:].mul(Drib_weights).sum(axis=1)
#               Player  SucDribble  Dribble  DribbleComp%  Combined
# 0         Max Aarons          33       78         42.31    153.31
# 1   Yunis Abdelhamid          16       22         72.73    110.73
# 2  Salis Abdul Samed          27       42         64.29    133.29
# 3    Laurent Abergel          42       65         64.62    171.62
# 4        Charles Abi           0        0           NaN      0.00

# %%
Indis_Stats = football_player_stats[["Player","YCards", "RCards", "FoulsCommitted"]]

Indis_weights = [1,1,1]
Indis_Stats["Combined"] = Indis_Stats.iloc[:,1:].mul(Indis_weights).sum(axis=1)

Indis_Stats.head()
# Out:
# /var/folders/73/tnh_dqbx3yv2n6cd0d_dbr5r0000gn/T/ipykernel_2726/765621768.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Indis_Stats["Combined"] = Indis_Stats.iloc[:,1:].mul(Indis_weights).sum(axis=1)
#               Player  YCards  RCards  FoulsCommitted  Combined
# 0         Max Aarons       8       0              31        39
# 1   Yunis Abdelhamid       5       1              43        49
# 2  Salis Abdul Samed      12       3              45        60
# 3    Laurent Abergel       9       0              46        55
# 4        Charles Abi       0       0               1         1

# %%
Composite_Table = pd.DataFrame()

Composite_Table["Player"] = Attack_Stats["Player"]
Composite_Table["Attack"] = Attack_Stats["Combined"]
Composite_Table["Pass"] = Pass_Stats["Combined"]
Composite_Table["Creativity"] = Crea_Stats["Combined"]
Composite_Table["Tackles"] = Tack_Stats["Combined"]
Composite_Table["Blocks"] = Block_Stats["Combined"]
Composite_Table["Dribbling"] = Drib_Stats["Combined"]
Composite_Table["Indiscipline"] = Indis_Stats["Combined"]
Composite_Table.head()
# Out:
#               Player  Attack     Pass  Creativity  Tackles  Blocks  Dribbling  \
# 0         Max Aarons   16.32  2603.56      131.78   131.36    2.72     153.31
# 1   Yunis Abdelhamid    6.46  2923.35       26.00   199.08    1.94     110.73
# 2  Salis Abdul Samed   13.28  3289.61       56.00   106.71    0.99     133.29
# 3    Laurent Abergel   12.97  3054.72      125.08   115.37    1.68     171.62
# 4        Charles Abi   24.00    41.33        1.00     1.00    2.00       0.00
#
#    Indiscipline
# 0            39
# 1            49
# 2            60
# 3            55
# 4             1
